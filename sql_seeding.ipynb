# %% [markdown]
# # SQL seeding

# %%
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd
from dotenv import load_dotenv
import os

# %%
# Load environment variables
load_dotenv()
sql_password = os.getenv("sql_password")

# %%
# Tus parámetros de conexión
bd = "popatoms"
password = sql_password  # Asegúrate de reemplazar esto con tu contraseña real
connection_string = 'mysql+pymysql://root:' + password + '@localhost/' + bd
engine = create_engine(connection_string)

# %% [markdown]
# ## Populate artist table

# %%
df_artists = pd.read_csv('sql_artist.csv') #, encoding='iso-8859-1',sep=';')

# %%
# Enviar DataFrame a MySQL
table_name = 'artist'
df_artists.to_sql(table_name, con=engine, if_exists='append', index=False)
# Out:
# 608

# %% [markdown]
# ## Populate chart table

# %%
chart = {'name': "'hot 100'", 
         "description": 'The week’s most popular current songs across all genres, ranked by streaming activity from digital music sources tracked by luminate, radio airplay audience impressions as measured by luminate and sales data as compiled by luminate.',
         "country": 'USA', 
         "frequency": 'week'}

# %%
df_chart = pd.DataFrame(chart, index=[1])

# %%
# Enviar DataFrame a MySQL
table_name = 'chart'
df_chart.to_sql(table_name, con=engine, if_exists='append', index=False)
# Out:
# 1

# %% [markdown]
# ## Populate chart_update table

# %%
chart_update = pd.read_csv('sql_chart_update.csv')

# %%
# Enviar DataFrame a MySQL
table_name = 'chart_update'
chart_update.to_sql(table_name, con=engine, if_exists='append', index=False)
# Out:
# 687

# %% [markdown]
# ## Populate track

# %%
track = pd.read_csv('sql_track.csv')

# %%
# Enviar DataFrame a MySQL
table_name = 'track'
track.to_sql(table_name, con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1' for key 'track.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[63], line 3
#       1 # Enviar DataFrame a MySQL
#       2 table_name = 'track'
# ----> 3 track.to_sql(table_name, con=engine, if_exists='append', index=False)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File ~/Code/.venv/lib/python3.12/site-packages/pandas/io/sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File ~/Code/.venv/lib/python3.12/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#     172         context._rowcount = rowcount
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     218         sql += b","
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#     222 return rows
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File ~/Code/.venv/lib/python3.12/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'track.PRIMARY'")
# [SQL: INSERT INTO track (track_id, title, title_spotify, album, colab, sp_id, release_date, peak_rank, peak_date, peak_year, lustrum, weeks, sp_popularity, tempo, duration, track_key, track_mode, danceability, energy, loudness, speechiness, acousticness, instrumentalness, liveness, valence, release_year, artist_id) VALUES (%(track_id)s, %(title)s, %(title_spotify)s, %(album)s, %(colab)s, %(sp_id)s, %(release_date)s, %(peak_rank)s, %(peak_date)s, %(peak_year)s, %(lustrum)s, %(weeks)s, %(sp_popularity)s, %(tempo)s, %(duration)s, %(track_key)s, %(track_mode)s, %(danceability)s, %(energy)s, %(loudness)s, %(speechiness)s, %(acousticness)s, %(instrumentalness)s, %(liveness)s, %(valence)s, %(release_year)s, %(artist_id)s)]
# [parameters: [{'track_id': 0, 'title': "('til) I Kissed You", 'title_spotify': "('Til) I Kissed You", 'album': 'The Fabulous Style Of The Everly Brothers', 'colab': 0, 'sp_id': '2ltpYs0O8uNesHFgGHg0bt', 'release_date': '1960-01-01', 'peak_rank': 4.0, 'peak_date': '1959-08-12', 'peak_year': 1959, 'lustrum': '1955-1959', 'weeks': 16.0, 'sp_popularity': 47.0, 'tempo': 141.087, 'duration': 145.96, 'track_key': 1.0, 'track_mode': 1.0, 'danceability': 0.569, 'energy': 0.465, 'loudness': -10.431, 'speechiness': 0.0438, 'acousticness': 0.614, 'instrumentalness': 0.0, 'liveness': 0.342, 'valence': 0.664, 'release_year': 1960, 'artist_id': 1.0}, {'track_id': 1, 'title': '(A Ship Will Come) Ein Schiff Wird Kommen', 'title_spotify': 'The Waltzing Cat', 'album': 'The Waltzing Cat', 'colab': 1, 'sp_id': '0rI1QQ8kMc7MH7LgnOPteX', 'release_date': '2004-02-14', 'peak_rank': 88.0, 'peak_date': '1961-04-19', 'peak_year': 1961, 'lustrum': '1960-1964', 'weeks': 4.0, 'sp_popularity': 37.0, 'tempo': 133.759, 'duration': 166.547, 'track_key': 7.0, 'track_mode': 1.0, 'danceability': 0.357, 'energy': 0.0663, 'loudness': -21.7, 'speechiness': 0.0415, 'acousticness': 0.983, 'instrumentalness': 0.68, 'liveness': 0.0553, 'valence': 0.246, 'release_year': 2004, 'artist_id': 2.0}, {'track_id': 2, 'title': '(All of a Sudden) My Heart Sings', 'title_spotify': '(All Of A Sudden) My Heart Sings - Remastered', 'album': 'My Heart Sings (Remastered)', 'colab': 0, 'sp_id': '0zKZqHPNUKjjhsUJHT06RZ', 'release_date': '1959-01-01', 'peak_rank': 15.0, 'peak_date': '1958-12-17', 'peak_year': 1958, 'lustrum': '1955-1959', 'weeks': 17.0, 'sp_popularity': 33.0, 'tempo': 111.446, 'duration': 182.56, 'track_key': 4.0, 'track_mode': 1.0, 'danceability': 0.435, 'energy': 0.36, 'loudness': -10.179, 'speechiness': 0.0298, 'acousticness': 0.78, 'instrumentalness': 0.0, 'liveness': 0.513, 'valence': 0.342, 'release_year': 1959, 'artist_id': 3.0}, {'track_id': 3, 'title': '(Baby) Hully Gully', 'title_spotify': 'Baby Hully Gully', 'album': "Doin' the Hully Gully", 'colab': 0, 'sp_id': '2CkbNJooPxUsHG4gFXKhxa', 'release_date': '1960-07-06', 'peak_rank': 72.0, 'peak_date': '1960-01-27', 'peak_year': 1960, 'lustrum': '1960-1964', 'weeks': 7.0, 'sp_popularity': 3.0, 'tempo': 115.772, 'duration': 218.642, 'track_key': 2.0, 'track_mode': 1.0, 'danceability': 0.699, 'energy': 0.661, 'loudness': -6.09, 'speechiness': 0.0382, 'acousticness': 0.516, 'instrumentalness': 0.0, 'liveness': 0.198, 'valence': 0.869, 'release_year': 1960, 'artist_id': 4.0}, {'track_id': 4, 'title': '(Dance The) Mess Around', 'title_spotify': 'Dance The Mess Around', 'album': "Dancin' Party: The Chubby Checker Collection (1960-1966)", 'colab': 0, 'sp_id': '58EirkLFB6O6wwRN9JowHB', 'release_date': '2020-06-19', 'peak_rank': 24.0, 'peak_date': '1961-04-19', 'peak_year': 1961, 'lustrum': '1960-1964', 'weeks': 7.0, 'sp_popularity': 18.0, 'tempo': 146.559, 'duration': 132.933, 'track_key': 10.0, 'track_mode': 1.0, 'danceability': 0.511, 'energy': 0.694, 'loudness': -5.509, 'speechiness': 0.0479, 'acousticness': 0.381, 'instrumentalness': 0.0, 'liveness': 0.195, 'valence': 0.826, 'release_year': 2020, 'artist_id': 5.0}, {'track_id': 5, 'title': '(Do The) Mashed Potatoes (Part 1)', 'title_spotify': '(Do The) Mashed Potatoes Part 1', 'album': 'Star Time', 'colab': 0, 'sp_id': '4W7ps5zORgRWe691hlxXzC', 'release_date': '1991-01-01', 'peak_rank': 84.0, 'peak_date': '1960-02-10', 'peak_year': 1960, 'lustrum': '1960-1964', 'weeks': 2.0, 'sp_popularity': 12.0, 'tempo': 134.471, 'duration': 112.4, 'track_key': 7.0, 'track_mode': 1.0, 'danceability': 0.745, 'energy': 0.837, 'loudness': -9.169, 'speechiness': 0.0467, 'acousticness': 0.511, 'instrumentalness': 0.339, 'liveness': 0.191, 'valence': 0.932, 'release_year': 1991, 'artist_id': 6.0}, {'track_id': 6, 'title': "(Doin' The) Lovers Leap", 'title_spotify': "(Doin' The) Lovers Leap", 'album': 'Hundred Year Webb, Vol. 2', 'colab': 0, 'sp_id': '2jX30KTWE5wQS7RdqvJO1X', 'release_date': ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
